# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
sns.boxplot(x='species', y='sepal_length', data=iris_data)

# %%
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=df['sepal_length'],y=df['petal_length'])
plt.show()

# %%
sns.scatterplot(x=df['sepal_length'], y=df['petal_length'], hue=df['species'])
plt.show()

# %%
sns.stripplot(x=df['species'], y=df['sepal_width'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.stripplot(x=df['species'], y=df['sepal_width'],palette=['r','g','y'])
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %%
sns.stripplot(x=df['species'], y=df['sepal_width'],palette=['chrome','black'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sns.stripplot(x=df['species'], y=df['sepal_width'],palette=['chrome','black'])
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2108, in stripplot(data, x, y, hue, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, hue_norm, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2106 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2107 color = _default_color(ax.scatter, hue, color, kwargs)
# -> 2108 edgecolor = p._complement_color(edgecolor, color, p._hue_map)
#    2110 kwargs.setdefault("zorder", 3)
#    2111 size = kwargs.get("s", size)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:332, in _CategoricalPlotter._complement_color(self, color, base_color, hue_map)
#     330     basis = [mpl.colors.to_rgb(base_color)]
# ...
