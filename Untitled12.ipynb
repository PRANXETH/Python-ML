# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame(np.random.rand(10, 5), columns=list('ABCDE'))

sns.heatmap(np.abs(df.corr()), cmap='Reds', annot=True, linewidths=0.5)

plt.show()

# %%
import seaborn as sns
import pandas as pd
import numpy as np

df=sns.load_dataset("tips")
df

df.describe()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame(np.random.rand(10, 5), columns=list('ABCDE'))

sns.heatmap(np.abs(df.corr()), cmap='YlOrBr', annot=True, linewidths=0.5)

plt.show()

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.514796   0.467219   0.435235   0.586518   0.438237
# std     0.257235   0.324418   0.317169   0.296747   0.280584
# min     0.105615   0.052648   0.017569   0.061797   0.149697
# 25%     0.424414   0.181399   0.126634   0.347695   0.183773
# 50%     0.502994   0.455723   0.483205   0.692779   0.413145
# 75%     0.652822   0.645524   0.644648   0.793906   0.534735
# max     0.943592   0.945562   0.944105   0.950130   0.925343

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
sc_array=sc.fit_transform(df)

# %%
sc_array.shape
# Out:
# (10, 5)

# %%
sc_df=pd.DataFrame(sc_array,columns=df.columns)
sc_df.head(5)
# Out:
#           A         B         C         D         E
# 0 -1.676733  0.623066 -1.207887  1.291605  0.066907
# 1 -0.079431 -1.236103  0.512337 -0.257471  0.318810
# 2  0.228121 -1.347016 -0.004375  0.808587 -1.048750
# 3  1.757112  1.505811 -1.388089 -1.863891 -0.255433
# 4  1.163691  1.554219  0.323224  0.520941 -1.083978

# %%
sc_df=pd.DataFrame(sc_array,columns=df.columns)
sc_df.head(3)
# Out:
#           A         B         C         D         E
# 0 -1.676733  0.623066 -1.207887  1.291605  0.066907
# 1 -0.079431 -1.236103  0.512337 -0.257471  0.318810
# 2  0.228121 -1.347016 -0.004375  0.808587 -1.048750
